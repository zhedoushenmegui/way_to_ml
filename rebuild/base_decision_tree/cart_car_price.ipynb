# %%
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split
import os
project_path = os.path.abspath(os.path.join(os.path.dirname(os.path.abspath('.')), '../'))
import sys
sys.path.append(project_path)
from util.visualization import draw_lines
from util.visualization import draw_scatters
from util.evaluate_process import classifier_evaluate, car_price_evaluate
from collections import Counter
from sklearn.metrics import auc, roc_curve

# %%
data_train = pd.read_csv(f'{project_path}/data/small_car_price_train.201908.csv')
data_test = pd.read_csv(f'{project_path}/data/small_car_price_test.201908.csv')

# %%
data_test.columns
# Out:
# Index(['c_price', 'max_price', 'min_price', 'dealer_price', 'car_model',
#        'fuel_type', 'register_city', 'model_generation',
#        'is_electric_skylight', 'is_panoramic_sunroof',
#        ...
#        'bottom_bigside_chromaticnum', 'bottom_bigside_weldnum',
#        'bottom_bigside_injurynum', 'bottom_bigside_injury_sagnum',
#        'bottom_bigside_injury_scratchnum', 'bottom_bigside_injury_brokennum',
#        'bottom_bigside_injury_scarsnum', 'bottom_bigside_injury_cracknum',
#        'bottom_bigside_repairnum', 'id'],
#       dtype='object', length=131)

# %%
from util.evaluate_process import car_price_evaluate
from util.visualization import draw_lines
from util.data_process import DataProcess

# %%
with open(f'{project_path}/data/car_price_feat.txt') as f:
    feat_list = list(filter(lambda x: x[0] != '#', f.read().split('\n')))

label_encode_map, f_map = DataProcess.gencode(pd.concat([data_train, data_test]), feat_list)
X_train, X_test = DataProcess.encode_process(data_train[feat_list], feat_list, label_encode_map), DataProcess.encode_process(data_test[feat_list], feat_list, label_encode_map)
y_train = data_train.price
y_test = data_test.price

# %%
def car_price_evaluate(target, pred, silent=0):
    if isinstance(target, pd.DataFrame):
        new_d_test = target.copy()
        new_d_test['pred'] = pred
    else:
        new_d_test = pd.DataFrame({'price': target, 'pred':pred})

    new_d_test['err'] = new_d_test.apply(lambda row: row.price - row.pred, axis=1)
    new_d_test['abserr'] = new_d_test.err.map(lambda x: abs(x))
    new_d_test['ape'] = new_d_test.apply(lambda row: row.abserr / row.price, axis=1)
    mape = np.mean(new_d_test.ape)
    accuracy5p = len(list(filter(lambda x: x <= 0.05, new_d_test.ape))) / len(new_d_test)
    msev = float(np.mean(new_d_test.err * new_d_test.err))
    rmse = np.sqrt(msev)
    if not silent:
        print(f'rmse: {round(rmse, 4)}')
        print(f'mse: {round(msev, 4)}')
        print(f'MAPE: {round(mape * 100, 2)}%')
        print(f'5%: {round(accuracy5p, 4) * 100}%')
    return {
        'rmse': round(rmse, 4),
        'mse': round(msev, 4),
        'mape': round(mape*100, 4),
        '5%': round(accuracy5p, 4) * 100
    }
# Out:
# rmse: 2.4969
# mse: 6.2344
# MAPE: 7.06%
# 5%: 45.61%
# {'rmse': 2.4969, 'mse': 6.2344, 'mape': 7.0601, '5%': 45.61}

# %%
def tree_to_dot(tree_dict, keys=None):
    # node: 0 [label="abc"];
    # line: 0 -> 1;
    if keys is None:
        keys = ['key', 'val', 'size', 'reason']
    nodes = [];
    lines = [];
    index = [0];
    def _process(struct, parent_id=None, path=''):
        cnt = '\\n'.join([f'{key}:{struct.get(key, "-")}' for key in keys])
        node = f'{index[0]} [label="{cnt}"];'
        nodes.append(node)
        if parent_id is not None:
            if path:
                lines.append(f'{parent_id} -> {index[0]} [headlabel="{path}"];')
            else:
                lines.append(f'{parent_id} -> {index[0]};')
        ###
        selfindex = index[0]
        index[0] += 1
        if 'trees' in struct:
            for v in struct['trees']:
                _process(struct['trees'][v], selfindex, path=v)
    ###
    _process(tree_dict)
    nodesstr = '\n'.join(nodes)
    linesstr = '\n'.join(lines)
    outputstr = 'digraph Tree {\nnode [shape=box] ;\n %s\n%s\n}' % (nodesstr, linesstr)
    return outputstr

## 这里dot 是一个绘图命令
## open 是mac 上的打开文件命令
def draw_tree(tree, save_path, keys=None):
    s = tree_to_dot(tree, keys)
    with open(f'{save_path}.dot', 'w') as f:
        f.write(s)
    os.system(f'dot -Tpng {save_path}.dot -o {save_path}.png && open {save_path}.png')

# %%
def lsd(arr):
    m = np.mean(arr)
    return sum([(x-m)**2 for x in arr])

def lad(arr):
    m = np.mean(arr)
    return sum([abs(x-m) for x in arr])

# %%
### 
def gen_tree_cart_reg(df, depth=0, min_samples_split=4, min_samples_leaf=2, max_depth=8, min_ms=4):
    ori_quota = lsd(df.target)
    size = len(df)
    ret = {
            'ori_quota': ori_quota,
            'size': size,
            'regval': np.mean(df.target),
            'depth': depth
    }
    if size < min_samples_split:
        # 这个节点数量太少, 不应该分裂
        ret['reason'] = 'less than min_samples_split'
        return ret
    if depth >= max_depth:
        # 太深了, 停止分裂
        ret['reason'] = 'to deep'
        return ret
    ###
    best_quota = 1
    best_key = None
    best_val = None
    ###
    for k in df.columns:
        if k == 'target':
            continue
        ## 其实可以在这里区分离散值和连续值, 来给出最好分裂点
        uniq_val = set(df[k])
        for v in uniq_val:
            ### 缺省值划分到 <=
            df1 = df[~(df[k] > v)]
            df2 = df[  df[k] > v ]
            if len(df1) == size or len(df1) == 0:
                continue
            quota1 = lsd(df1.target)
            quota2 = lsd(df2.target)
            new_quota = quota1 + quota2
            if best_key is None or new_quota < best_quota:
                best_key = k
                best_val = v
                best_quota = new_quota
    ###
    ret['best_quota'] = best_quota
    ret['key'] = best_key
    ret['val'] = best_val
    df1 = df[~(df[best_key] > best_val)]
    df2 = df[  df[best_key] > best_val ]
    ret['leaf_num'] = [len(df1), len(df2)]
    if len(df1) < min_samples_leaf or len(df2) < min_samples_leaf:
        # 子节点数量过少, 不应该分裂
        ret['reason'] = 'leaf samples less than min_samples_leaf'
        return ret
    tree1 = gen_tree_cart_reg(df1, depth=depth+1)
    tree2 = gen_tree_cart_reg(df2, depth=depth+1)
    ret['trees'] = {}
    ret['trees']['<='] = tree1
    ret['trees']['>'] = tree2
    return ret

def predict_process_cart_reg(cart_tree, data):
    prob = 0
    label = cart_tree['regval']
    ####
    if 'trees' in cart_tree:
        key = cart_tree['key']
        val = cart_tree['val']
        condition = '>' if data[key] > val else '<='
        tree = cart_tree['trees'][condition]
        ret = predict_process_cart_reg(tree, data)
        label = ret[0]
        prob = ret[1]
    return label, prob

    
def predict_cart_reg(cart_tree, df):
    d11 = df.to_dict()
    size = len(df)
    d12 = [{k: d11[k][i] for k in d11} for i in df.index]
    preds = []
    probs = []
    for data in d12:
        ret = predict_process_cart_reg(cart_tree, data)
        preds.append(ret[0])
        probs.append(ret[1])
    return preds, probs

# %%
rdf = X_train.copy()
rdf['target'] = y_train
adt = gen_tree_cart_reg(rdf, max_depth=10)
adt
# Out:
# {'ori_quota': 62415.53526871712,
#  'size': 1509,
#  'regval': 27.012158714380387,
#  'depth': 0,
#  'best_quota': 28711.611049271465,
#  'key': 'used_months',
#  'val': 56,
#  'leaf_num': [879, 630],
#  'trees': {'<=': {'ori_quota': 14440.467480773605,
#    'size': 879,
#    'regval': 31.013185437997723,
#    'depth': 1,
#    'best_quota': 9369.693195228836,
#    'key': 'used_months',
#    'val': 18,
#    'leaf_num': [81, 798],
#    'trees': {'<=': {'ori_quota': 1374.045283950617,
#      'size': 81,
#      'regval': 38.55197530864198,
#      'depth': 2,
#      'best_quota': 805.9157334149329,
#      'key': 'car_height',
#      'val': 1.49,
#      'leaf_num': [38, 43],
#      'trees': {'<=': {'ori_quota': 228.47974736842122,
#        'size': 38,
#        'regval': 35.73473684210527,
#        'depth': 3,
#        'best_quota': 133.3252190476191,
#        'key': 'edition',
#        'val': 4,
#        'leaf_num': [14, 24],
#        'trees': {'<=': {'ori_quota': 26.963085714285725,
#          'size': 14,
#          'regval': 33.66285714285714,
#          'depth': 4,
#          'best_quota': 14.146160000000013,
#          'key': 'mileage',
#          'val': 2.16,
#          'leaf_num': [10, 4],
#          'trees': {'<=': {'ori_quota': 11.556160000000016,
#            'size': 10,
#            'regval': 34.267999999999994,
#            'depth': 5,
#            'best_quota': 3.9755555555555526,
#            'key': 'deal_city',
#            'val': 85,
#            'leaf_num': [9, 1],
#            'reason': 'leaf samples less than min_samples_leaf'},
#           '>': {'ori_quota': 2.589999999999996,
#            'size': 4,
#            'regval': 32.15,
#            'depth': 5,
#            'best_quota': 0.34000000000000113,
#            'key': 'region',
#            'val': 4,
#            'leaf_num': [2, 2],
#            'trees': {'<=': {'ori_quota': 0.02000000000000057,
#              'size': 2,
#              'regval': 32.9,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 0.32000000000000056,
#              'size': 2,
#              'regval': 31.4,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}}}},
#         '>': {'ori_quota': 106.36213333333338,
#          'size': 24,
#          'regval': 36.943333333333335,
#          'depth': 4,
#          'best_quota': 76.25511578947372,
#          'key': 'used_months',
#          'val': 17,
#          'leaf_num': [19, 5],
#          'trees': {'<=': {'ori_quota': 70.60311578947372,
#            'size': 19,
#            'regval': 37.51789473684211,
#            'depth': 5,
#            'best_quota': 39.116193333333314,
#            'key': 'mileage',
#            'val': 3.06,
#            'leaf_num': [15, 4],
#            'trees': {'<=': {'ori_quota': 26.18869333333331,
#              'size': 15,
#              'regval': 38.18266666666667,
#              'depth': 6,
#              'best_quota': 19.74676666666666,
#              'key': 'used_months',
#              'val': 10,
#              'leaf_num': [3, 12],
#              'trees': {'<=': {'ori_quota': 0.4802666666666636,
#                'size': 3,
#                'regval': 39.49333333333333,
#                'depth': 7,
#                'reason': 'less than min_samples_split'},
#               '>': {'ori_quota': 19.266499999999994,
#                'size': 12,
#                'regval': 37.855,
#                'depth': 7,
#                'best_quota': 11.09684000000001,
#                'key': 'mileage',
#                'val': 2.7,
#                'leaf_num': [10, 2],
#                'trees': {'<=': {'ori_quota': 11.07684000000001,
#                  'size': 10,
#                  'regval': 37.486,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.01999999999999915,
#                  'size': 2,
#                  'regval': 39.7,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}}}},
#             '>': {'ori_quota': 12.927500000000009,
#              'size': 4,
#              'regval': 35.025,
#              'depth': 6,
#              'best_quota': 1.1266666666666665,
#              'key': 'door_metal',
#              'val': 0,
#              'leaf_num': [3, 1],
#              'reason': 'leaf samples less than min_samples_leaf'}}},
#           '>': {'ori_quota': 5.652000000000005,
#            'size': 5,
#            'regval': 34.760000000000005,
#            'depth': 5,
#            'best_quota': 1.544999999999999,
#            'key': 'deal_city',
#            'val': 10,
#            'leaf_num': [2, 3],
#            'trees': {'<=': {'ori_quota': 0.044999999999999145,
#              'size': 2,
#              'regval': 33.65,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 1.5,
#              'size': 3,
#              'regval': 35.5,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}}}}}},
#       '>': {'ori_quota': 577.4359860465116,
#        'size': 43,
#        'regval': 41.04162790697674,
#        'depth': 3,
#        'best_quota': 532.5068355113636,
#        'key': 'edition',
#        'val': 3,
#        'leaf_num': [11, 32],
#        'trees': {'<=': {'ori_quota': 7.05636363636364,
#          'size': 11,
#          'regval': 39.29818181818182,
#          'depth': 4,
#          'best_quota': 4.556853333333342,
#          'key': 'gdp_level',
#          'val': 1,
#          'leaf_num': [5, 6],
#          'trees': {'<=': {'ori_quota': 2.5235200000000058,
#            'size': 5,
#            'regval': 38.775999999999996,
#            'depth': 5,
#            'best_quota': 0.5162666666666696,
#            'key': 'used_months',
#            'val': 8,
#            'leaf_num': [3, 2],
#            'trees': {'<=': {'ori_quota': 0.5162666666666696,
#              'size': 3,
#              'regval': 39.29333333333333,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 0.0,
#              'size': 2,
#              'regval': 38.0,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}},
#           '>': {'ori_quota': 2.033333333333336,
#            'size': 6,
#            'regval': 39.733333333333334,
#            'depth': 5,
#            'best_quota': 0.9066666666666677,
#            'key': 'used_months',
#            'val': 6,
#            'leaf_num': [3, 3],
#            'trees': {'<=': {'ori_quota': 0.16666666666666666,
#              'size': 3,
#              'regval': 40.166666666666664,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 0.7400000000000011,
#              'size': 3,
#              'regval': 39.300000000000004,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}}}},
#         '>': {'ori_quota': 525.4504718750001,
#          'size': 32,
#          'regval': 41.64093750000001,
#          'depth': 4,
#          'best_quota': 474.9826541176469,
#          'key': 'gdp_level',
#          'val': 1,
#          'leaf_num': [17, 15],
#          'trees': {'<=': {'ori_quota': 364.9152941176469,
#            'size': 17,
#            'regval': 42.82058823529412,
#            'depth': 5,
#            'best_quota': 250.37769230769226,
#            'key': 'mileage',
#            'val': 1.78,
#            'leaf_num': [13, 4],
#            'trees': {'<=': {'ori_quota': 65.37769230769226,
#              'size': 13,
#              'regval': 41.38076923076923,
#              'depth': 6,
#              'best_quota': 49.241999999999976,
#              'key': 'used_months',
#              'val': 2,
#              'leaf_num': [5, 8],
#              'trees': {'<=': {'ori_quota': 30.241999999999976,
#                'size': 5,
#                'regval': 42.79,
#                'depth': 7,
#                'best_quota': 12.286874999999984,
#                'key': 'deal_city',
#                'val': 84,
#                'leaf_num': [4, 1],
#                'reason': 'leaf samples less than min_samples_leaf'},
#               '>': {'ori_quota': 19.0,
#                'size': 8,
#                'regval': 40.5,
#                'depth': 7,
#                'best_quota': 2.8666666666666663,
#                'key': 'mileage',
#                'val': 0.71,
#                'leaf_num': [3, 5],
#                'trees': {'<=': {'ori_quota': 1.1666666666666667,
#                  'size': 3,
#                  'regval': 38.666666666666664,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'},
#                 '>': {'ori_quota': 1.6999999999999997,
#                  'size': 5,
#                  'regval': 41.6,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 185.0,
#              'size': 4,
#              'regval': 47.5,
#              'depth': 6,
#              'best_quota': 8.666666666666666,
#              'key': 'deal_city',
#              'val': 9,
#              'leaf_num': [3, 1],
#              'reason': 'leaf samples less than min_samples_leaf'}}},
#           '>': {'ori_quota': 110.06736000000002,
#            'size': 15,
#            'regval': 40.303999999999995,
#            'depth': 5,
#            'best_quota': 59.177169230769245,
#            'key': 'deal_city',
#            'val': 5,
#            'leaf_num': [2, 13],
#            'trees': {'<=': {'ori_quota': 18.0,
#              'size': 2,
#              'regval': 45.0,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 41.177169230769245,
#              'size': 13,
#              'regval': 39.58153846153846,
#              'depth': 6,
#              'best_quota': 27.28080000000001,
#              'key': 'mileage',
#              'val': 2.16,
#              'leaf_num': [12, 1],
#              'reason': 'leaf samples less than min_samples_leaf'}}}}}}}}},
#     '>': {'ori_quota': 7995.647911278218,
#      'size': 798,
#      'regval': 30.247969924812026,
#      'depth': 2,
#      'best_quota': 5745.689842142279,
#      'key': 'used_months',
#      'val': 43,
#      'leaf_num': [500, 298],
#      'trees': {'<=': {'ori_quota': 3943.074840799997,
#        'size': 500,
#        'regval': 31.544280000000004,
#        'depth': 3,
#        'best_quota': 3095.765351548438,
#        'key': 'edition',
#        'val': 4,
#        'leaf_num': [147, 353],
#        'trees': {'<=': {'ori_quota': 587.428082993197,
#          'size': 147,
#          'regval': 29.52700680272109,
#          'depth': 4,
#          'best_quota': 451.53263439933255,
#          'key': 'mileage',
#          'val': 7.2,
#          'leaf_num': [116, 31],
#          'trees': {'<=': {'ori_quota': 365.6369956896551,
#            'size': 116,
#            'regval': 30.02405172413793,
#            'depth': 5,
#            'best_quota': 308.0175239892182,
#            'key': 'used_months',
#            'val': 28,
#            'leaf_num': [53, 63],
#            'trees': {'<=': {'ori_quota': 143.3569811320754,
#              'size': 53,
#              'regval': 30.79245283018868,
#              'depth': 6,
#              'best_quota': 112.87242857142857,
#              'key': 'spray_num',
#              'val': 1,
#              'leaf_num': [18, 35],
#              'trees': {'<=': {'ori_quota': 36.12499999999999,
#                'size': 18,
#                'regval': 31.849999999999998,
#                'depth': 7,
#                'best_quota': 26.399740259740252,
#                'key': 'model_age',
#                'val': 1,
#                'leaf_num': [11, 7],
#                'trees': {'<=': {'ori_quota': 12.105454545454549,
#                  'size': 11,
#                  'regval': 31.263636363636362,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 14.294285714285703,
#                  'size': 7,
#                  'regval': 32.77142857142857,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 76.74742857142859,
#                'size': 35,
#                'regval': 30.24857142857143,
#                'depth': 7,
#                'best_quota': 62.28235294117644,
#                'key': 'mileage',
#                'val': 1.81,
#                'leaf_num': [1, 34],
#                'reason': 'leaf samples less than min_samples_leaf'}}},
#             '>': {'ori_quota': 164.66054285714281,
#              'size': 63,
#              'regval': 29.377619047619046,
#              'depth': 6,
#              'best_quota': 138.17804107142865,
#              'key': 'model_age',
#              'val': 3,
#              'leaf_num': [7, 56],
#              'trees': {'<=': {'ori_quota': 6.429485714285715,
#                'size': 7,
#                'regval': 31.211428571428574,
#                'depth': 7,
#                'best_quota': 3.841320000000001,
#                'key': 'color',
#                'val': 3,
#                'leaf_num': [5, 2],
#                'trees': {'<=': {'ori_quota': 3.716320000000001,
#                  'size': 5,
#                  'regval': 31.596000000000004,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.125,
#                  'size': 2,
#                  'regval': 30.25,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 131.74855535714295,
#                'size': 56,
#                'regval': 29.148392857142856,
#                'depth': 7,
#                'best_quota': 107.78249818181821,
#                'key': 'door_flaw',
#                'val': 5,
#                'leaf_num': [55, 1],
#                'reason': 'leaf samples less than min_samples_leaf'}}}}},
#           '>': {'ori_quota': 85.89563870967741,
#            'size': 31,
#            'regval': 27.667096774193542,
#            'depth': 5,
#            'best_quota': 59.51842400000002,
#            'key': 'used_months',
#            'val': 31,
#            'leaf_num': [6, 25],
#            'trees': {'<=': {'ori_quota': 2.674999999999998,
#              'size': 6,
#              'regval': 29.55,
#              'depth': 6,
#              'best_quota': 0.7999999999999999,
#              'key': 'fender_flaw',
#              'val': 2,
#              'leaf_num': [5, 1],
#              'reason': 'leaf samples less than min_samples_leaf'},
#             '>': {'ori_quota': 56.84342400000002,
#              'size': 25,
#              'regval': 27.2152,
#              'depth': 6,
#              'best_quota': 42.63017575757578,
#              'key': 'deal_city',
#              'val': 85,
#              'leaf_num': [22, 3],
#              'trees': {'<=': {'ori_quota': 41.48990909090911,
#                'size': 22,
#                'regval': 27.493636363636366,
#                'depth': 7,
#                'best_quota': 27.55417904761906,
#                'key': 'fender_spray',
#                'val': 2,
#                'leaf_num': [15, 7],
#                'trees': {'<=': {'ori_quota': 14.779893333333343,
#                  'size': 15,
#                  'regval': 28.037333333333336,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 12.774285714285718,
#                  'size': 7,
#                  'regval': 26.32857142857143,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 1.1402666666666672,
#                'size': 3,
#                'regval': 25.173333333333332,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}}}}}},
#         '>': {'ori_quota': 2508.3372685552413,
#          'size': 353,
#          'regval': 32.384334277620404,
#          'depth': 4,
#          'best_quota': 2025.6632447390134,
#          'key': 'used_months',
#          'val': 30,
#          'leaf_num': [131, 222],
#          'trees': {'<=': {'ori_quota': 691.0749541984727,
#            'size': 131,
#            'regval': 33.90656488549618,
#            'depth': 5,
#            'best_quota': 584.92657537594,
#            'key': 'mileage',
#            'val': 6.77,
#            'leaf_num': [112, 19],
#            'trees': {'<=': {'ori_quota': 486.2549964285717,
#              'size': 112,
#              'regval': 34.277321428571426,
#              'depth': 6,
#              'best_quota': 440.65343243243245,
#              'key': 'displacement',
#              'val': 2.0,
#              'leaf_num': [111, 1],
#              'reason': 'leaf samples less than min_samples_leaf'},
#             '>': {'ori_quota': 98.6715789473684,
#              'size': 19,
#              'regval': 31.721052631578942,
#              'depth': 6,
#              'best_quota': 67.97192307692308,
#              'key': 'mileage',
#              'val': 8.92,
#              'leaf_num': [13, 6],
#              'trees': {'<=': {'ori_quota': 58.77692307692307,
#                'size': 13,
#                'regval': 32.58461538461539,
#                'depth': 7,
#                'best_quota': 43.26,
#                'key': 'deal_city',
#                'val': 0,
#                'leaf_num': [1, 12],
#                'reason': 'leaf samples less than min_samples_leaf'},
#               '>': {'ori_quota': 9.195,
#                'size': 6,
#                'regval': 29.849999999999998,
#                'depth': 7,
#                'best_quota': 3.648000000000001,
#                'key': 'driving_seat_abrasion',
#                'val': 0,
#                'leaf_num': [5, 1],
#                'reason': 'leaf samples less than min_samples_leaf'}}}}},
#           '>': {'ori_quota': 1334.5882905405408,
#            'size': 222,
#            'regval': 31.486081081081085,
#            'depth': 5,
#            'best_quota': 1136.0173086757993,
#            'key': 'max_horse_power',
#            'val': 9,
#            'leaf_num': [219, 3],
#            'trees': {'<=': {'ori_quota': 1091.6906420091327,
#              'size': 219,
#              'regval': 31.375388127853885,
#              'depth': 6,
#              'best_quota': 920.7657219799491,
#              'key': 'mileage',
#              'val': 5.81,
#              'leaf_num': [114, 105],
#              'trees': {'<=': {'ori_quota': 551.9446991228065,
#                'size': 114,
#                'regval': 32.22324561403509,
#                'depth': 7,
#                'best_quota': 468.8522759615382,
#                'key': 'bumper_flaw',
#                'val': 2,
#                'leaf_num': [104, 10],
#                'trees': {'<=': {'ori_quota': 442.23127596153824,
#                  'size': 104,
#                  'regval': 32.48798076923077,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 26.621000000000002,
#                  'size': 10,
#                  'regval': 29.47,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 368.8210228571427,
#                'size': 105,
#                'regval': 30.454857142857144,
#                'depth': 7,
#                'best_quota': 341.7020648876404,
#                'key': 'color',
#                'val': 2,
#                'leaf_num': [16, 89],
#                'trees': {'<=': {'ori_quota': 26.839375,
#                  'size': 16,
#                  'regval': 29.25625,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 314.8626898876404,
#                  'size': 89,
#                  'regval': 30.670337078651684,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 44.326666666666654,
#              'size': 3,
#              'regval': 39.56666666666667,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}}}}}},
#       '>': {'ori_quota': 1802.6150013422816,
#        'size': 298,
#        'regval': 28.07295302013423,
#        'depth': 3,
#        'best_quota': 1526.4680845298162,
#        'key': 'edition',
#        'val': 4,
#        'leaf_num': [80, 218],
#        'trees': {'<=': {'ori_quota': 268.16249875,
#          'size': 80,
#          'regval': 26.483875,
#          'depth': 4,
#          'best_quota': 199.47723831908831,
#          'key': 'mileage',
#          'val': 6.07,
#          'leaf_num': [26, 54],
#          'trees': {'<=': {'ori_quota': 72.6729846153846,
#            'size': 26,
#            'regval': 27.819230769230767,
#            'depth': 5,
#            'best_quota': 52.63298095238096,
#            'key': 'used_months',
#            'val': 51,
#            'leaf_num': [21, 5],
#            'trees': {'<=': {'ori_quota': 49.70498095238096,
#              'size': 21,
#              'regval': 28.247619047619043,
#              'depth': 6,
#              'best_quota': 38.63059999999997,
#              'key': 'gdp_level',
#              'val': 3,
#              'leaf_num': [20, 1],
#              'reason': 'leaf samples less than min_samples_leaf'},
#             '>': {'ori_quota': 2.928000000000001,
#              'size': 5,
#              'regval': 26.02,
#              'depth': 6,
#              'best_quota': 0.346666666666667,
#              'key': 'door_metal',
#              'val': 0,
#              'leaf_num': [3, 2],
#              'trees': {'<=': {'ori_quota': 0.32666666666666716,
#                'size': 3,
#                'regval': 25.433333333333334,
#                'depth': 7,
#                'reason': 'less than min_samples_split'},
#               '>': {'ori_quota': 0.019999999999999858,
#                'size': 2,
#                'regval': 26.9,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}}}},
#           '>': {'ori_quota': 126.8042537037037,
#            'size': 54,
#            'regval': 25.840925925925927,
#            'depth': 5,
#            'best_quota': 107.9525158562368,
#            'key': 'mileage',
#            'val': 9.89,
#            'leaf_num': [43, 11],
#            'trees': {'<=': {'ori_quota': 91.69069767441862,
#              'size': 43,
#              'regval': 26.13976744186047,
#              'depth': 6,
#              'best_quota': 69.50864960317458,
#              'key': 'gdp_level',
#              'val': 2,
#              'leaf_num': [36, 7],
#              'trees': {'<=': {'ori_quota': 55.43916388888887,
#                'size': 36,
#                'regval': 25.823055555555555,
#                'depth': 7,
#                'best_quota': 38.158314381270905,
#                'key': 'spray_num',
#                'val': 3,
#                'leaf_num': [13, 23],
#                'trees': {'<=': {'ori_quota': 13.666523076923074,
#                  'size': 13,
#                  'regval': 26.744615384615386,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 24.49179130434783,
#                  'size': 23,
#                  'regval': 25.30217391304348,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 14.06948571428571,
#                'size': 7,
#                'regval': 27.76857142857143,
#                'depth': 7,
#                'best_quota': 5.365333333333329,
#                'key': 'deal_city',
#                'val': 67,
#                'leaf_num': [6, 1],
#                'reason': 'leaf samples less than min_samples_leaf'}}},
#             '>': {'ori_quota': 16.26181818181818,
#              'size': 11,
#              'regval': 24.672727272727276,
#              'depth': 6,
#              'best_quota': 6.058749999999993,
#              'key': 'deal_city',
#              'val': 34,
#              'leaf_num': [3, 8],
#              'trees': {'<=': {'ori_quota': 0.5399999999999983,
#                'size': 3,
#                'regval': 23.099999999999998,
#                'depth': 7,
#                'reason': 'less than min_samples_split'},
#               '>': {'ori_quota': 5.5187499999999945,
#                'size': 8,
#                'regval': 25.2625,
#                'depth': 7,
#                'best_quota': 2.3600000000000008,
#                'key': 'region',
#                'val': 4,
#                'leaf_num': [7, 1],
#                'reason': 'leaf samples less than min_samples_leaf'}}}}}}},
#         '>': {'ori_quota': 1258.3055857798163,
#          'size': 218,
#          'regval': 28.656100917431196,
#          'depth': 4,
#          'best_quota': 1036.2927021868052,
#          'key': 'mileage',
#          'val': 6.81,
#          'leaf_num': [76, 142],
#          'trees': {'<=': {'ori_quota': 337.5602789473682,
#            'size': 76,
#            'regval': 30.03552631578948,
#            'depth': 5,
#            'best_quota': 300.5537,
#            'key': 'tire_flaw',
#            'val': 0,
#            'leaf_num': [72, 4],
#            'trees': {'<=': {'ori_quota': 293.9262,
#              'size': 72,
#              'regval': 30.199999999999996,
#              'depth': 6,
#              'best_quota': 262.59719999999993,
#              'key': 'used_months',
#              'val': 45,
#              'leaf_num': [12, 60],
#              'trees': {'<=': {'ori_quota': 41.14249999999998,
#                'size': 12,
#                'regval': 31.674999999999997,
#                'depth': 7,
#                'best_quota': 8.462222222222216,
#                'key': 'region',
#                'val': 3,
#                'leaf_num': [9, 3],
#                'trees': {'<=': {'ori_quota': 6.035555555555552,
#                  'size': 9,
#                  'regval': 30.72222222222222,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 2.4266666666666636,
#                  'size': 3,
#                  'regval': 34.53333333333333,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 221.45469999999997,
#                'size': 60,
#                'regval': 29.905000000000005,
#                'depth': 7,
#                'best_quota': 194.2856895833334,
#                'key': 'deal_city',
#                'val': 12,
#                'leaf_num': [12, 48],
#                'trees': {'<=': {'ori_quota': 15.806091666666664,
#                  'size': 12,
#                  'regval': 28.559166666666666,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 178.47959791666673,
#                  'size': 48,
#                  'regval': 30.241458333333338,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 6.627500000000001,
#              'size': 4,
#              'regval': 27.075000000000003,
#              'depth': 6,
#              'best_quota': 0.8866666666666669,
#              'key': 'bumper_flaw',
#              'val': 0,
#              'leaf_num': [1, 3],
#              'reason': 'leaf samples less than min_samples_leaf'}}},
#           '>': {'ori_quota': 698.7324232394369,
#            'size': 142,
#            'regval': 27.91781690140845,
#            'depth': 5,
#            'best_quota': 605.4937606299211,
#            'key': 'mileage',
#            'val': 13.26,
#            'leaf_num': [127, 15],
#            'trees': {'<=': {'ori_quota': 579.538360629921,
#              'size': 127,
#              'regval': 28.196299212598426,
#              'depth': 6,
#              'best_quota': 518.3872371717173,
#              'key': 'used_months',
#              'val': 50,
#              'leaf_num': [72, 55],
#              'trees': {'<=': {'ori_quota': 302.8634444444445,
#                'size': 72,
#                'regval': 28.80277777777778,
#                'depth': 7,
#                'best_quota': 248.90062685788791,
#                'key': 'metal_num',
#                'val': 2,
#                'leaf_num': [59, 13],
#                'trees': {'<=': {'ori_quota': 210.36425762711866,
#                  'size': 59,
#                  'regval': 29.209152542372884,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 38.536369230769246,
#                  'size': 13,
#                  'regval': 26.95846153846154,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 215.52379272727273,
#                'size': 55,
#                'regval': 27.402363636363635,
#                'depth': 7,
#                'best_quota': 169.56921280193237,
#                'key': 'displacement',
#                'val': 2.0,
#                'leaf_num': [46, 9],
#                'trees': {'<=': {'ori_quota': 128.76752391304348,
#                  'size': 46,
#                  'regval': 26.998043478260865,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 40.8016888888889,
#                  'size': 9,
#                  'regval': 29.46888888888889,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 25.955400000000004,
#              'size': 15,
#              'regval': 25.56,
#              'depth': 6,
#              'best_quota': 14.471025000000001,
#              'key': 'deal_city',
#              'val': 12,
#              'leaf_num': [3, 12],
#              'trees': {'<=': {'ori_quota': 1.7365999999999997,
#                'size': 3,
#                'regval': 27.310000000000002,
#                'depth': 7,
#                'reason': 'less than min_samples_split'},
#               '>': {'ori_quota': 12.734425000000002,
#                'size': 12,
#                'regval': 25.122500000000002,
#                'depth': 7,
#                'best_quota': 6.392422222222224,
#                'key': 'chromatic_num',
#                'val': 0,
#                'leaf_num': [9, 3],
#                'trees': {'<=': {'ori_quota': 6.368355555555557,
#                  'size': 9,
#                  'regval': 25.54222222222222,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.024066666666666087,
#                  'size': 3,
#                  'regval': 23.863333333333333,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}}}}}}}}}}}}}},
#   '>': {'ori_quota': 14271.143568497859,
#    'size': 630,
#    'regval': 21.42977380952381,
#    'depth': 1,
#    'best_quota': 5128.048165668692,
#    'key': 'car_length',
#    'val': 4.98,
#    'leaf_num': [74, 556],
#    'trees': {'<=': {'ori_quota': 454.5444121621622,
#      'size': 74,
#      'regval': 10.987432432432433,
#      'depth': 2,
#      'best_quota': 220.10281533333324,
#      'key': 'used_months',
#      'val': 112,
#      'leaf_num': [50, 24],
#      'trees': {'<=': {'ori_quota': 142.62368199999992,
#        'size': 50,
#        'regval': 12.2206,
#        'depth': 3,
#        'best_quota': 115.18445000000003,
#        'key': 'mileage',
#        'val': 9.87,
#        'leaf_num': [18, 32],
#        'trees': {'<=': {'ori_quota': 63.50124999999999,
#          'size': 18,
#          'regval': 13.208333333333336,
#          'depth': 4,
#          'best_quota': 44.89764705882353,
#          'key': 'deal_city',
#          'val': 52,
#          'leaf_num': [17, 1],
#          'reason': 'leaf samples less than min_samples_leaf'},
#         '>': {'ori_quota': 51.68320000000003,
#          'size': 32,
#          'regval': 11.665,
#          'depth': 4,
#          'best_quota': 33.23813333333334,
#          'key': 'bumper_change',
#          'val': 1,
#          'leaf_num': [24, 8],
#          'trees': {'<=': {'ori_quota': 22.21813333333333,
#            'size': 24,
#            'regval': 12.103333333333333,
#            'depth': 5,
#            'best_quota': 17.152382608695653,
#            'key': 'pillar_flaw',
#            'val': 4,
#            'leaf_num': [23, 1],
#            'reason': 'leaf samples less than min_samples_leaf'},
#           '>': {'ori_quota': 11.020000000000003,
#            'size': 8,
#            'regval': 10.35,
#            'depth': 5,
#            'best_quota': 2.994285714285715,
#            'key': 'deal_city',
#            'val': 52,
#            'leaf_num': [7, 1],
#            'reason': 'leaf samples less than min_samples_leaf'}}}}},
#       '>': {'ori_quota': 77.47913333333332,
#        'size': 24,
#        'regval': 8.418333333333333,
#        'depth': 3,
#        'best_quota': 25.55753142857143,
#        'key': 'used_months',
#        'val': 126,
#        'leaf_num': [14, 10],
#        'trees': {'<=': {'ori_quota': 11.985971428571423,
#          'size': 14,
#          'regval': 9.661428571428571,
#          'depth': 4,
#          'best_quota': 7.065257142857139,
#          'key': 'gdp_level',
#          'val': 0,
#          'leaf_num': [7, 7],
#          'trees': {'<=': {'ori_quota': 5.459771428571425,
#            'size': 7,
#            'regval': 10.254285714285714,
#            'depth': 5,
#            'best_quota': 0.9841999999999991,
#            'key': 'color',
#            'val': 3,
#            'leaf_num': [5, 2],
#            'trees': {'<=': {'ori_quota': 0.9119999999999995,
#              'size': 5,
#              'regval': 10.760000000000002,
#              'depth': 6,
#              'best_quota': 0.1899999999999999,
#              'key': 'bumper_change',
#              'val': 0,
#              'leaf_num': [4, 1],
#              'reason': 'leaf samples less than min_samples_leaf'},
#             '>': {'ori_quota': 0.07219999999999963,
#              'size': 2,
#              'regval': 8.99,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}},
#           '>': {'ori_quota': 1.605485714285714,
#            'size': 7,
#            'regval': 9.06857142857143,
#            'depth': 5,
#            'best_quota': 0.5933333333333333,
#            'key': 'displacement',
#            'val': 2.5,
#            'leaf_num': [6, 1],
#            'reason': 'leaf samples less than min_samples_leaf'}}},
#         '>': {'ori_quota': 13.571560000000005,
#          'size': 10,
#          'regval': 6.678,
#          'depth': 4,
#          'best_quota': 7.273000000000003,
#          'key': 'car_height',
#          'val': 1.47,
#          'leaf_num': [6, 4],
#          'trees': {'<=': {'ori_quota': 5.083000000000002,
#            'size': 6,
#            'regval': 6.03,
#            'depth': 5,
#            'best_quota': 1.7122000000000008,
#            'key': 'edition',
#            'val': 1,
#            'leaf_num': [2, 4],
#            'trees': {'<=': {'ori_quota': 0.07219999999999996,
#              'size': 2,
#              'regval': 7.09,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 1.6400000000000008,
#              'size': 4,
#              'regval': 5.5,
#              'depth': 6,
#              'best_quota': 0.20000000000000037,
#              'key': 'deal_city',
#              'val': 9,
#              'leaf_num': [2, 2],
#              'trees': {'<=': {'ori_quota': 0.020000000000000035,
#                'size': 2,
#                'regval': 6.1,
#                'depth': 7,
#                'reason': 'less than min_samples_split'},
#               '>': {'ori_quota': 0.18000000000000033,
#                'size': 2,
#                'regval': 4.9,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}}}},
#           '>': {'ori_quota': 2.1900000000000017,
#            'size': 4,
#            'regval': 7.65,
#            'depth': 5,
#            'best_quota': 0.42666666666666647,
#            'key': 'edition',
#            'val': 4,
#            'leaf_num': [1, 3],
#            'reason': 'leaf samples less than min_samples_leaf'}}}}}}},
#     '>': {'ori_quota': 4673.503753506529,
#      'size': 556,
#      'regval': 22.819581834532375,
#      'depth': 2,
#      'best_quota': 2881.543098645455,
#      'key': 'used_months',
#      'val': 70,
#      'leaf_num': [273, 283],
#      'trees': {'<=': {'ori_quota': 1519.5857269204375,
#        'size': 273,
#        'regval': 24.647424175824174,
#        'depth': 3,
#        'best_quota': 1349.118187129784,
#        'key': 'used_months',
#        'val': 66,
#        'leaf_num': [192, 81],
#        'trees': {'<=': {'ori_quota': 1007.9536119791667,
#          'size': 192,
#          'regval': 25.160677083333336,
#          'depth': 4,
#          'best_quota': 798.7737765151514,
#          'key': 'edition',
#          'val': 4,
#          'leaf_num': [60, 132],
#          'trees': {'<=': {'ori_quota': 146.69832500000004,
#            'size': 60,
#            'regval': 23.6125,
#            'depth': 5,
#            'best_quota': 105.26189230769232,
#            'key': 'mileage',
#            'val': 10.12,
#            'leaf_num': [39, 21],
#            'trees': {'<=': {'ori_quota': 68.90989230769232,
#              'size': 39,
#              'regval': 24.22230769230769,
#              'depth': 6,
#              'best_quota': 55.42987096774194,
#              'key': 'region',
#              'val': 4,
#              'leaf_num': [31, 8],
#              'trees': {'<=': {'ori_quota': 49.52767096774194,
#                'size': 31,
#                'regval': 24.520967741935483,
#                'depth': 7,
#                'best_quota': 42.82121071428572,
#                'key': 'metal_num',
#                'val': 3,
#                'leaf_num': [28, 3],
#                'trees': {'<=': {'ori_quota': 41.36121071428572,
#                  'size': 28,
#                  'regval': 24.673214285714284,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 1.4599999999999989,
#                  'size': 3,
#                  'regval': 23.099999999999998,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 5.9022,
#                'size': 8,
#                'regval': 23.064999999999998,
#                'depth': 7,
#                'best_quota': 1.2909333333333333,
#                'key': 'color',
#                'val': 3,
#                'leaf_num': [6, 2],
#                'trees': {'<=': {'ori_quota': 1.1659333333333333,
#                  'size': 6,
#                  'regval': 23.503333333333334,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.125,
#                  'size': 2,
#                  'regval': 21.75,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}}}},
#             '>': {'ori_quota': 36.352000000000004,
#              'size': 21,
#              'regval': 22.48,
#              'depth': 6,
#              'best_quota': 25.35927368421053,
#              'key': 'driving_seat_flaw',
#              'val': 0,
#              'leaf_num': [19, 2],
#              'trees': {'<=': {'ori_quota': 25.23427368421053,
#                'size': 19,
#                'regval': 22.714736842105264,
#                'depth': 7,
#                'best_quota': 15.977766666666673,
#                'key': 'front_light_change',
#                'val': 0,
#                'leaf_num': [16, 3],
#                'trees': {'<=': {'ori_quota': 15.297500000000007,
#                  'size': 16,
#                  'regval': 22.412499999999998,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.6802666666666664,
#                  'size': 3,
#                  'regval': 24.326666666666668,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 0.125,
#                'size': 2,
#                'regval': 20.25,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}}}},
#           '>': {'ori_quota': 652.0754515151514,
#            'size': 132,
#            'regval': 25.86439393939394,
#            'depth': 5,
#            'best_quota': 585.4382884792628,
#            'key': 'mileage',
#            'val': 9.58,
#            'leaf_num': [62, 70],
#            'trees': {'<=': {'ori_quota': 317.14557419354844,
#              'size': 62,
#              'regval': 26.61935483870968,
#              'depth': 6,
#              'best_quota': 261.4006966666667,
#              'key': 'spray_num',
#              'val': 5,
#              'leaf_num': [30, 32],
#              'trees': {'<=': {'ori_quota': 176.75674666666671,
#                'size': 30,
#                'regval': 27.598666666666663,
#                'depth': 7,
#                'best_quota': 145.9548714285714,
#                'key': 'mileage',
#                'val': 3.39,
#                'leaf_num': [2, 28],
#                'trees': {'<=': {'ori_quota': 12.40020000000002,
#                  'size': 2,
#                  'regval': 31.39,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'},
#                 '>': {'ori_quota': 133.5546714285714,
#                  'size': 28,
#                  'regval': 27.32785714285714,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 84.64395,
#                'size': 32,
#                'regval': 25.701249999999998,
#                'depth': 7,
#                'best_quota': 59.119949206349204,
#                'key': 'fender_spray',
#                'val': 2,
#                'leaf_num': [14, 18],
#                'trees': {'<=': {'ori_quota': 14.42217142857142,
#                  'size': 14,
#                  'regval': 24.688571428571432,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 44.69777777777779,
#                  'size': 18,
#                  'regval': 26.48888888888889,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 268.29271428571434,
#              'size': 70,
#              'regval': 25.19571428571429,
#              'depth': 6,
#              'best_quota': 219.67863777089786,
#              'key': 'displacement',
#              'val': 2.5,
#              'leaf_num': [51, 19],
#              'trees': {'<=': {'ori_quota': 131.9446588235294,
#                'size': 51,
#                'regval': 24.687058823529412,
#                'depth': 7,
#                'best_quota': 116.33457272727274,
#                'key': 'mileage',
#                'val': 14.13,
#                'leaf_num': [44, 7],
#                'trees': {'<=': {'ori_quota': 104.83457272727274,
#                  'size': 44,
#                  'regval': 24.907727272727275,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 11.500000000000002,
#                  'size': 7,
#                  'regval': 23.3,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 87.73397894736844,
#                'size': 19,
#                'regval': 26.56105263157895,
#                'depth': 7,
#                'best_quota': 64.84445641025641,
#                'key': 'mileage',
#                'val': 10.92,
#                'leaf_num': [6, 13],
#                'trees': {'<=': {'ori_quota': 3.20753333333334,
#                  'size': 6,
#                  'regval': 28.176666666666666,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 61.63692307692307,
#                  'size': 13,
#                  'regval': 25.815384615384616,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}}}}}},
#         '>': {'ori_quota': 341.1645751506173,
#          'size': 81,
#          'regval': 23.430824691358026,
#          'depth': 4,
#          'best_quota': 301.1138620544652,
#          'key': 'mileage',
#          'val': 8.32,
#          'leaf_num': [19, 62],
#          'trees': {'<=': {'ori_quota': 54.912578947368424,
#            'size': 19,
#            'regval': 24.701052631578946,
#            'depth': 5,
#            'best_quota': 41.08979642857143,
#            'key': 'door_metal',
#            'val': 0,
#            'leaf_num': [12, 7],
#            'trees': {'<=': {'ori_quota': 27.323025000000005,
#              'size': 12,
#              'regval': 25.352499999999996,
#              'depth': 6,
#              'best_quota': 19.568610000000014,
#              'key': 'displacement',
#              'val': 2.5,
#              'leaf_num': [10, 2],
#              'trees': {'<=': {'ori_quota': 16.443610000000014,
#                'size': 10,
#                'regval': 24.993000000000002,
#                'depth': 7,
#                'best_quota': 7.153075000000002,
#                'key': 'region',
#                'val': 3,
#                'leaf_num': [6, 4],
#                'trees': {'<=': {'ori_quota': 7.004000000000001,
#                  'size': 6,
#                  'regval': 25.78,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.1490750000000007,
#                  'size': 4,
#                  'regval': 23.812499999999996,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 3.125,
#                'size': 2,
#                'regval': 27.15,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}},
#             '>': {'ori_quota': 13.766771428571431,
#              'size': 7,
#              'regval': 23.584285714285716,
#              'depth': 6,
#              'best_quota': 3.59788,
#              'key': 'deal_city',
#              'val': 9,
#              'leaf_num': [5, 2],
#              'trees': {'<=': {'ori_quota': 3.0776800000000004,
#                'size': 5,
#                'regval': 22.822,
#                'depth': 7,
#                'best_quota': 0.8254000000000008,
#                'key': 'fender_metal',
#                'val': 1,
#                'leaf_num': [2, 3],
#                'trees': {'<=': {'ori_quota': 0.5,
#                  'size': 2,
#                  'regval': 22.0,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'},
#                 '>': {'ori_quota': 0.3254000000000008,
#                  'size': 3,
#                  'regval': 23.37,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 0.5201999999999996,
#                'size': 2,
#                'regval': 25.490000000000002,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}}}},
#           '>': {'ori_quota': 246.20128310709674,
#            'size': 62,
#            'regval': 23.041561290322576,
#            'depth': 5,
#            'best_quota': 217.33881136226063,
#            'key': 'deal_city',
#            'val': 74,
#            'leaf_num': [49, 13],
#            'trees': {'<=': {'ori_quota': 177.6031344391837,
#              'size': 49,
#              'regval': 23.392995918367344,
#              'depth': 6,
#              'best_quota': 132.5080442819048,
#              'key': 'deal_city',
#              'val': 57,
#              'leaf_num': [42, 7],
#              'trees': {'<=': {'ori_quota': 110.75090142476193,
#                'size': 42,
#                'regval': 23.001352380952383,
#                'depth': 7,
#                'best_quota': 95.52458023214854,
#                'key': 'deal_city',
#                'val': 5,
#                'leaf_num': [13, 29],
#                'trees': {'<=': {'ori_quota': 38.846262990769226,
#                  'size': 13,
#                  'regval': 22.10206153846154,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 56.678317241379304,
#                  'size': 29,
#                  'regval': 23.40448275862069,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 21.75714285714286,
#                'size': 7,
#                'regval': 25.742857142857144,
#                'depth': 7,
#                'best_quota': 2.5533333333333315,
#                'key': 'deal_city',
#                'val': 72,
#                'leaf_num': [6, 1],
#                'reason': 'leaf samples less than min_samples_leaf'}}},
#             '>': {'ori_quota': 39.73567692307694,
#              'size': 13,
#              'regval': 21.716923076923077,
#              'depth': 6,
#              'best_quota': 23.696819047619044,
#              'key': 'metal_num',
#              'val': 1,
#              'leaf_num': [7, 6],
#              'trees': {'<=': {'ori_quota': 12.608485714285713,
#                'size': 7,
#                'regval': 20.68857142857143,
#                'depth': 7,
#                'best_quota': 3.7512,
#                'key': 'metal_num',
#                'val': 0,
#                'leaf_num': [5, 2],
#                'trees': {'<=': {'ori_quota': 3.6999999999999997,
#                  'size': 5,
#                  'regval': 21.4,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.05120000000000009,
#                  'size': 2,
#                  'regval': 18.91,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 11.088333333333333,
#                'size': 6,
#                'regval': 22.916666666666668,
#                'depth': 7,
#                'best_quota': 1.1119999999999992,
#                'key': 'deal_city',
#                'val': 78,
#                'leaf_num': [1, 5],
#                'reason': 'leaf samples less than min_samples_leaf'}}}}}}}}},
#       '>': {'ori_quota': 1361.9573717250175,
#        'size': 283,
#        'regval': 21.056327561837456,
#        'depth': 3,
#        'best_quota': 1198.5230379867353,
#        'key': 'used_months',
#        'val': 81,
#        'leaf_num': [160, 123],
#        'trees': {'<=': {'ori_quota': 660.7601583119383,
#          'size': 160,
#          'regval': 21.722629375000004,
#          'depth': 4,
#          'best_quota': 582.9587977743589,
#          'key': 'mileage',
#          'val': 12.88,
#          'leaf_num': [121, 39],
#          'trees': {'<=': {'ori_quota': 406.6804387999999,
#            'size': 121,
#            'regval': 22.118518181818178,
#            'depth': 5,
#            'best_quota': 381.31611225748094,
#            'key': 'displacement',
#            'val': 2.5,
#            'leaf_num': [100, 21],
#            'trees': {'<=': {'ori_quota': 289.3717313051,
#              'size': 100,
#              'regval': 21.908707000000003,
#              'depth': 6,
#              'best_quota': 266.699055268672,
#              'key': 'door_spray',
#              'val': 2,
#              'leaf_num': [66, 34],
#              'trees': {'<=': {'ori_quota': 188.21420820984847,
#                'size': 66,
#                'regval': 22.25046515151515,
#                'depth': 7,
#                'best_quota': 168.60990052818713,
#                'key': 'bumper_flaw',
#                'val': 0,
#                'leaf_num': [9, 57],
#                'trees': {'<=': {'ori_quota': 13.646088888888892,
#                  'size': 9,
#                  'regval': 20.878888888888888,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 154.96381163929823,
#                  'size': 57,
#                  'regval': 22.467029824561404,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 78.48484705882352,
#                'size': 34,
#                'regval': 21.245294117647056,
#                'depth': 7,
#                'best_quota': 64.13284545454546,
#                'key': 'metal_num',
#                'val': 1,
#                'leaf_num': [12, 22],
#                'trees': {'<=': {'ori_quota': 25.957499999999992,
#                  'size': 12,
#                  'regval': 22.125,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 38.175345454545464,
#                  'size': 22,
#                  'regval': 20.765454545454546,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 91.94438095238093,
#              'size': 21,
#              'regval': 23.11761904761905,
#              'depth': 6,
#              'best_quota': 67.96262777777777,
#              'key': 'bumper_flaw',
#              'val': 2,
#              'leaf_num': [18, 3],
#              'trees': {'<=': {'ori_quota': 67.96262777777777,
#                'size': 18,
#                'regval': 23.553888888888892,
#                'depth': 7,
#                'best_quota': 47.9922275,
#                'key': 'bumper_spray',
#                'val': 1,
#                'leaf_num': [10, 8],
#                'trees': {'<=': {'ori_quota': 36.70464,
#                  'size': 10,
#                  'regval': 24.496,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 11.2875875,
#                  'size': 8,
#                  'regval': 22.37625,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 0.0,
#                'size': 3,
#                'regval': 20.5,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}}}},
#           '>': {'ori_quota': 176.278358974359,
#            'size': 39,
#            'regval': 20.494358974358974,
#            'depth': 5,
#            'best_quota': 145.02052027027025,
#            'key': 'max_horse_power',
#            'val': 9,
#            'leaf_num': [37, 2],
#            'trees': {'<=': {'ori_quota': 144.42647027027024,
#              'size': 37,
#              'regval': 20.286216216216214,
#              'depth': 6,
#              'best_quota': 123.38350205882355,
#              'key': 'door_spray',
#              'val': 2,
#              'leaf_num': [17, 20],
#              'trees': {'<=': {'ori_quota': 68.34864705882353,
#                'size': 17,
#                'regval': 19.468235294117648,
#                'depth': 7,
#                'best_quota': 50.09167692307692,
#                'key': 'fender_spray',
#                'val': 2,
#                'leaf_num': [13, 4],
#                'trees': {'<=': {'ori_quota': 20.871676923076922,
#                  'size': 13,
#                  'regval': 20.043076923076924,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 29.219999999999995,
#                  'size': 4,
#                  'regval': 17.6,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 55.034855000000015,
#                'size': 20,
#                'regval': 20.981500000000004,
#                'depth': 7,
#                'best_quota': 44.15069166666666,
#                'key': 'door_spray',
#                'val': 3,
#                'leaf_num': [8, 12],
#                'trees': {'<=': {'ori_quota': 18.1846,
#                  'size': 8,
#                  'regval': 21.884999999999998,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 25.966091666666664,
#                  'size': 12,
#                  'regval': 20.379166666666666,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}},
#             '>': {'ori_quota': 0.5940499999999999,
#              'size': 2,
#              'regval': 24.345,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}}}},
#         '>': {'ori_quota': 537.7628796747969,
#          'size': 123,
#          'regval': 20.189593495934957,
#          'depth': 4,
#          'best_quota': 439.8245811965807,
#          'key': 'engine_intake_form',
#          'val': 0,
#          'leaf_num': [6, 117],
#          'trees': {'<=': {'ori_quota': 48.74700000000001,
#            'size': 6,
#            'regval': 24.13,
#            'depth': 5,
#            'best_quota': 12.338933333333339,
#            'key': 'mileage',
#            'val': 7.97,
#            'leaf_num': [3, 3],
#            'trees': {'<=': {'ori_quota': 7.672266666666672,
#              'size': 3,
#              'regval': 26.593333333333334,
#              'depth': 6,
#              'reason': 'less than min_samples_split'},
#             '>': {'ori_quota': 4.666666666666667,
#              'size': 3,
#              'regval': 21.666666666666668,
#              'depth': 6,
#              'reason': 'less than min_samples_split'}}},
#           '>': {'ori_quota': 391.0775811965807,
#            'size': 117,
#            'regval': 19.987521367521367,
#            'depth': 5,
#            'best_quota': 340.51418611111126,
#            'key': 'mileage',
#            'val': 8.98,
#            'leaf_num': [36, 81],
#            'trees': {'<=': {'ori_quota': 109.17583055555558,
#              'size': 36,
#              'regval': 20.97361111111111,
#              'depth': 6,
#              'best_quota': 82.13200294117647,
#              'key': 'used_months',
#              'val': 94,
#              'leaf_num': [34, 2],
#              'trees': {'<=': {'ori_quota': 81.41200294117647,
#                'size': 34,
#                'regval': 21.183823529411764,
#                'depth': 7,
#                'best_quota': 66.10582187499998,
#                'key': 'tire_flaw',
#                'val': 0,
#                'leaf_num': [32, 2],
#                'trees': {'<=': {'ori_quota': 66.10582187499998,
#                  'size': 32,
#                  'regval': 21.3515625,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 0.0,
#                  'size': 2,
#                  'regval': 18.5,
#                  'depth': 8,
#                  'reason': 'less than min_samples_split'}}},
#               '>': {'ori_quota': 0.7199999999999991,
#                'size': 2,
#                'regval': 17.4,
#                'depth': 7,
#                'reason': 'less than min_samples_split'}}},
#             '>': {'ori_quota': 231.33835555555567,
#              'size': 81,
#              'regval': 19.54925925925926,
#              'depth': 6,
#              'best_quota': 200.40487792207793,
#              'key': 'displacement',
#              'val': 2.5,
#              'leaf_num': [70, 11],
#              'trees': {'<=': {'ori_quota': 165.8735142857143,
#                'size': 70,
#                'regval': 19.304285714285715,
#                'depth': 7,
#                'best_quota': 140.38047708333326,
#                'key': 'used_months',
#                'val': 93,
#                'leaf_num': [64, 6],
#                'trees': {'<=': {'ori_quota': 136.72714374999993,
#                  'size': 64,
#                  'regval': 19.4890625,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 3.6533333333333307,
#                  'size': 6,
#                  'regval': 17.333333333333332,
#                  'depth': 8,
#                  'reason': 'to deep'}}},
#               '>': {'ori_quota': 34.53136363636363,
#                'size': 11,
#                'regval': 21.10818181818182,
#                'depth': 7,
#                'best_quota': 16.004442857142852,
#                'key': 'transfer_times',
#                'val': 0,
#                'leaf_num': [4, 7],
#                'trees': {'<=': {'ori_quota': 7.567499999999999,
#                  'size': 4,
#                  'regval': 22.825,
#                  'depth': 8,
#                  'reason': 'to deep'},
#                 '>': {'ori_quota': 8.436942857142853,
#                  'size': 7,
#                  'regval': 20.127142857142854,
#                  'depth': 8,
#                  'reason': 'to deep'}}}}}}}}}}}}}}}}}

# %%
draw_tree(adt, 'cart_reg_price', keys=['key', 'val', 'ori_quota', 'size', 'regval', 'reason'])

# %%
## 测试集表现
pred, prob = predict_cart_reg(adt, X_test)
car_price_evaluate(target=y_test, pred=pred)

dldf = pd.DataFrame({'car_id':[f'_{x}' for x in data_test.id], 'price': y_test, 'pred': pred})
dldf.sort_values(by='price', inplace=True)
draw_lines(dldf.car_id, [dldf.price, dldf.pred], ['price', 'pred'])
# Out:
# rmse: 2.4969
# mse: 6.2344
# MAPE: 7.06%
# 5%: 45.61%
# <div>
#
#
#             <div id="cadc5eef-536b-4e96-accd-2ce3478ae997" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cadc5eef-536b-4e96-accd-2ce3478ae997")) {
#                     Plotly.newPlot(
#                         'cadc5eef-536b-4e96-accd-2ce3478ae997',
#                         [{"mode": "lines+markers", "name": "price", "type": "scatter", "x": ["_163653", "_141626", "_141625", "_141382", "_115570", "_169632", "_116358", "_142417", "_146160", "_169740", "_140442", "_139609", "_159734", "_169146", "_151779", "_156320", "_125422", "_162937", "_121874", "_126004", "_161205", "_149611", "_133512", "_167298", "_148372", "_161315", "_126254", "_130296", "_122559", "_122558", "_132526", "_116761", "_152694", "_139965", "_133698", "_133730", "_163187", "_137970", "_134827", "_164952", "_156377", "_129359", "_134239", "_147195", "_126450", "_125890", "_125774", "_121242", "_164622", "_170388", "_161428", "_124773", "_143148", "_138411", "_118236", "_113149", "_148736", "_169807", "_169085", "_159454", "_127217", "_131786", "_112880", "_157771", "_140183", "_121063", "_164440", "_154431", "_154826", "_140804", "_130891", "_157115", "_126297", "_130563", "_157648", "_169076", "_125281", "_150453", "_132953", "_121653", "_130254", "_124312", "_124313", "_135250", "_143332", "_164905", "_148022", "_160205", "_130671", "_149749", "_116404", "_129033", "_169892", "_137942", "_141002", "_145795", "_141001", "_151675", "_117980", "_140362", "_122862", "_133051", "_133266", "_166269", "_112129", "_143353", "_135486", "_131966", "_140255", "_165157", "_140254", "_159036", "_149411", "_142848", "_155926", "_126024", "_122029", "_116539", "_129500", "_129319", "_131250", "_155192", "_117645", "_169832", "_129937", "_128726", "_129004", "_148708", "_113795", "_137402", "_136660", "_115907", "_115908", "_147304", "_125497", "_163587", "_135592", "_143672", "_140265", "_121532", "_168349", "_116553", "_125365", "_137636", "_126293", "_116691", "_161654", "_126184", "_147362", "_129982", "_163170", "_163168", "_164725", "_110889", "_112923", "_126633", "_113709", "_157795", "_129559", "_157280", "_140263", "_111482", "_158887", "_112304", "_167966", "_159150", "_132898", "_153430", "_129666", "_116349", "_115650", "_121868", "_141162", "_158051", "_121528", "_140073", "_144644", "_139570", "_161865", "_165500", "_114376", "_136960", "_136214", "_165790", "_166213", "_134620", "_133731", "_112299", "_168394", "_128664", "_128840", "_130388", "_170749", "_130042", "_138193", "_146897", "_139571", "_151335", "_149090", "_120442", "_152119", "_148065", "_156897", "_154978", "_152733", "_115211", "_115212", "_140340", "_169564", "_161489", "_130045", "_122699", "_162116", "_135710", "_114758", "_151672", "_129871", "_131238", "_117014", "_150552", "_146523", "_168809", "_150081", "_135425", "_155687", "_136039", "_166966", "_136166", "_133269", "_135946", "_127212", "_158949", "_158948", "_132398", "_149846", "_123332", "_170111", "_131851", "_166714", "_152173", "_119666", "_157943", "_146972", "_167798", "_148985", "_155149", "_163743", "_136967", "_162387", "_112651", "_128641", "_161590", "_112900", "_147827", "_170319", "_130549", "_129192", "_169851", "_116474", "_112517", "_117262", "_122350", "_125978", "_127118", "_150338", "_165230", "_141803", "_155082", "_115636", "_141062", "_151224", "_161566", "_111662", "_140365", "_145150", "_168240", "_130727", "_157302", "_113966", "_126307", "_163315", "_134411", "_147399", "_110945", "_134936", "_111217", "_134405", "_148059", "_142106", "_142051", "_159616", "_164821", "_142009", "_142008", "_118106", "_129479", "_133926", "_130194", "_113377", "_151459", "_112216", "_167295", "_158379", "_123357", "_148533", "_140605", "_119338", "_142064", "_134114", "_150815", "_153984", "_118186", "_157326", "_153972", "_144404", "_144272", "_152452", "_143768", "_155815", "_160953", "_123776", "_123777", "_132814", "_139948", "_125391", "_117771", "_114347", "_125909", "_155055", "_167069", "_115466", "_118245", "_134715", "_119876", "_155240", "_130744", "_113521", "_113816", "_169994", "_120253", "_143851", "_118532", "_158285", "_120751", "_122047", "_142083", "_164119", "_142388", "_131543", "_131544", "_125209", "_162513", "_145805", "_153800", "_170532", "_ ...

# %%
# 训练集
pred, prob = predict_cart_reg(adt, X_train)
car_price_evaluate(target=y_train, pred=pred)

dldf = pd.DataFrame({'car_id':[f'_{x}' for x in data_train.id], 'price': y_train, 'pred': pred})
dldf.sort_values(by='price', inplace=True)
draw_lines(dldf.car_id, [dldf.price, dldf.pred], ['price', 'pred'])
# Out:
# rmse: 1.6369
# mse: 2.6795
# MAPE: 4.62%
# 5%: 64.48%
# <div>
#
#
#             <div id="36fe9a82-39a2-48cf-9df7-c88dbbc7a3bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("36fe9a82-39a2-48cf-9df7-c88dbbc7a3bd")) {
#                     Plotly.newPlot(
#                         '36fe9a82-39a2-48cf-9df7-c88dbbc7a3bd',
#                         [{"mode": "lines+markers", "name": "price", "type": "scatter", "x": ["_98016", "_4038", "_80391", "_20044", "_2776", "_83739", "_78527", "_33823", "_65322", "_46751", "_58552", "_93155", "_82057", "_21214", "_51568", "_97565", "_95085", "_110599", "_98654", "_35053", "_94176", "_89488", "_3827", "_56882", "_88046", "_109920", "_48246", "_41708", "_80425", "_96715", "_99015", "_51114", "_90842", "_80310", "_2668", "_18607", "_27866", "_109149", "_61480", "_48520", "_1843", "_34275", "_32624", "_24545", "_17926", "_16254", "_68627", "_26111", "_47745", "_43744", "_20163", "_29147", "_61327", "_16343", "_50832", "_52650", "_48342", "_29144", "_11085", "_30528", "_17282", "_2966", "_65085", "_63763", "_71663", "_78124", "_87845", "_8634", "_80886", "_81199", "_85182", "_85431", "_38352", "_62884", "_63342", "_92975", "_31745", "_56143", "_107049", "_56339", "_87626", "_31694", "_85812", "_94533", "_63096", "_88917", "_42664", "_23776", "_21325", "_90616", "_77442", "_30883", "_75940", "_101756", "_60585", "_11966", "_14120", "_55687", "_39317", "_15742", "_14568", "_76159", "_110016", "_58953", "_103437", "_5238", "_106573", "_91451", "_38797", "_78770", "_92127", "_88288", "_13839", "_77298", "_100710", "_58549", "_109703", "_46620", "_60894", "_107534", "_43132", "_15870", "_38673", "_11790", "_85996", "_93789", "_9247", "_67059", "_60466", "_20950", "_58928", "_36723", "_61847", "_31415", "_44106", "_88757", "_43451", "_51967", "_50971", "_22434", "_12409", "_76046", "_104719", "_22680", "_93964", "_43722", "_3495", "_90129", "_79105", "_41169", "_24181", "_41537", "_77980", "_14479", "_27063", "_74884", "_88479", "_28649", "_58478", "_94263", "_7245", "_14037", "_22743", "_109302", "_40214", "_105273", "_97454", "_107668", "_20957", "_70490", "_89044", "_19753", "_67365", "_102804", "_89570", "_75956", "_109981", "_68044", "_57043", "_57765", "_57097", "_24411", "_27511", "_25194", "_26093", "_57522", "_37100", "_98748", "_41444", "_86801", "_15416", "_27973", "_8587", "_94612", "_62768", "_9314", "_91033", "_61944", "_9875", "_41418", "_19652", "_89598", "_2506", "_22154", "_78432", "_50927", "_46850", "_50458", "_51698", "_85818", "_7251", "_66458", "_55180", "_59385", "_59386", "_92551", "_59067", "_29717", "_102329", "_20256", "_66601", "_41235", "_69718", "_94532", "_24919", "_68771", "_96962", "_98211", "_52149", "_47095", "_106192", "_46541", "_31450", "_26289", "_76343", "_77061", "_41889", "_75152", "_35403", "_15863", "_36417", "_23279", "_25499", "_42272", "_2913", "_103523", "_110230", "_110231", "_50749", "_40589", "_84543", "_74894", "_2526", "_15238", "_31285", "_105179", "_60449", "_41544", "_38786", "_14060", "_1432", "_107624", "_58176", "_11157", "_25530", "_41021", "_54684", "_56762", "_8140", "_24734", "_9637", "_78358", "_73235", "_77551", "_54836", "_27008", "_82022", "_105021", "_89732", "_61969", "_101459", "_39507", "_38405", "_65780", "_16338", "_18509", "_17125", "_90438", "_58032", "_39127", "_57997", "_27966", "_80232", "_106355", "_56941", "_80882", "_89053", "_40927", "_24613", "_56631", "_18144", "_29155", "_58659", "_13735", "_38795", "_91659", "_45279", "_71043", "_16225", "_38913", "_31564", "_60845", "_70712", "_47642", "_30374", "_99309", "_70687", "_48387", "_49012", "_77458", "_84025", "_24063", "_57917", "_845", "_50731", "_78508", "_27634", "_45404", "_61685", "_40118", "_67740", "_77214", "_104465", "_6239", "_66963", "_56002", "_17551", "_89185", "_88986", "_23847", "_99810", "_85393", "_29908", "_8153", "_103392", "_46030", "_103312", "_80234", "_72300", "_24129", "_103111", "_11121", "_23683", "_70745", "_60593", "_91985", "_109593", "_24037", "_21294", "_65555", "_12055", "_53167", "_59738", "_28089", "_7671", "_69739", "_86201", "_11070", "_76381", "_71086", "_30364", "_48779", "_42005", "_57325", "_26986", "_107159", "_60802", "_4395", "_100430", "_11819", "_85170", "_32605", "_43036", "_24166", "_82961", "_7739", "_105313", "_84717", "_74786", "_101987", ...
